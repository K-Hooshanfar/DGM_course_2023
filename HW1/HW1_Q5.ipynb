# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("ngaussian (1).csv" , delimiter=' ',header=None)

# %%
df
# Out:
#             0         1
# 0   -1.727048 -3.599960
# 1   -1.445891 -3.270109
# 2   -0.458869 -1.148513
# 3    1.317966  2.516560
# 4    1.153506  2.006051
# ..        ...       ...
# 995  2.068504  5.060544
# 996 -2.633527 -5.427452
# 997  1.200837  1.701804
# 998 -2.797796 -5.378348
# 999 -1.159075 -1.555699
#
# [1000 rows x 2 columns]

# %%
X1=df[0].values.reshape(-1, 1)  
X2=df[1].values.reshape(-1, 1)

# %%
plt.scatter(X1, X2 , label='Original Data')
plt.legend()
plt.xlabel('X1')
plt.ylabel('X2')
plt.title("X1 vs X2")
plt.show()

# %% [markdown]
# SCM M1

# %%
model = LinearRegression(fit_intercept=False)

# Fit the model to the data
model.fit(X1, X2)

intercept = model.intercept_  
slope12 = model.coef_[0]  

print(f"B12 is: {slope12}")
# Out:
# B12 is: [2.00326517]

# %%
plt.scatter(X1, X2-slope12*X1)
plt.xlabel('X1')
plt.ylabel('X2-slope12*X1')
plt.show()

# %% [markdown]
# SCM M2

# %%
model = LinearRegression(fit_intercept=False)

# Fit the model to the data
model.fit(X2, X1)

intercept = model.intercept_  
slope21 = model.coef_[0]  

print(f"B21 is: {slope21}")
# Out:
# B21 is: [0.48538]

# %%
plt.scatter(X2, X1-slope21*X2)
plt.xlabel('X2')
plt.ylabel('X1-slope21*X2')
plt.show()
